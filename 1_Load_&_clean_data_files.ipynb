# %% [markdown]
# <a href="https://colab.research.google.com/github/zakaria-aabbou/Covid_19_topic_modeling/blob/main/1_Load_%26_clean_data_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load & clean data files
# -------------------------------------------------
#
# ### Dataset description:
#
# In response to the COVID-19 pandemic, the White House and a coalition of leading research groups have prepared the COVID-19 Open Research Dataset (CORD-19). CORD-19 is a resource of over 57,000 scholarly articles, including over 45,000 with full text, about COVID-19, SARS-CoV-2, and related coronaviruses. This freely available dataset is provided to the global research community to apply recent advances in natural language processing and other AI techniques to generate new insights in support of the ongoing fight against this infectious disease. There is a growing urgency for these approaches because of the rapid acceleration in new coronavirus literature, making it difficult for the medical research community to keep up.
#
# This dataset was created by the Allen Institute for AI in partnership with the Chan Zuckerberg Initiative, Georgetown University’s Center for Security and Emerging Technology, Microsoft Research, and the National Library of Medicine - National Institutes of Health, in coordination with The White House Office of Science and Technology Policy.
#
#
# Our goal here is to grab all the json files that contain the liturature for each paper and merge them to the metadata.csv file accordingly and output the result to a new .csv file to be used for our final capstone.
#
# ### Notebook content:
#
#
# #### 1. Import libraries & load meta data

# %%
import numpy as np
import pandas as pd
import os
import json
import glob
import sys
sys.path.insert(0, "../")

root_path = 'CORD-19-research-challenge/'

# %%
# List all files in directory:
# !ls CORD-19-research-challenge
# Out:
# COVID.DATA.LIC.AGMT.pdf cord_19_embeddings_4_17 metadata.csv
# biorxiv_medrxiv         custom_license          metadata.readme
# comm_use_subset         json_schema.txt         noncomm_use_subset

# %%
# Load the metadata dataset:
root_path = 'CORD-19-research-challenge'
metadata_path = f'{root_path}/metadata.csv'
meta_df = pd.read_csv(metadata_path, dtype={
    'pubmed_id': str,
    'Microsoft Academic Paper ID': str, 
    'doi': str
})
meta_df.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  zjufx4fo  b2897e1277f56641193a6db73825f707eed3e4c9      PMC
# 1  ymceytj3  e3d0d482ebd9a8ba81c254cc433f314142e72174      PMC
# 2  wzj2glte  00b1d99e70f779eb4ede50059db469c65e8c1469      PMC
# 3  2sfqsfm1  cf584e00f637cbd8f1bb35f3f09f5ed07b71aeb0      PMC
# 4  i0zym7iq  dde02f11923815e6a16a31dd6298c46b109c5dfa      PMC
#
#                                                title  \
# 0  Sequence requirements for RNA strand transfer ...
# 1  Crystal structure of murine sCEACAM1a[1,4]: a ...
# 2  Synthesis of a novel hepatitis C virus protein...
# 3  Structure of coronavirus main proteinase revea...
# 4  Discontinuous and non-discontinuous subgenomic...
#
#                         doi      pmcid pubmed_id license  \
# 0  10.1093/emboj/20.24.7220  PMC125340  11742998     unk
# 1   10.1093/emboj/21.9.2076  PMC125375  11980704     unk
# 2  10.1093/emboj/20.14.3840  PMC125543  11447125   no-cc
# 3      10.1093/emboj/cdf327  PMC126080  12093723     unk
# 4      10.1093/emboj/cdf635  PMC136939  12456663     unk
#
#                                             abstract publish_time  \
# 0  Nidovirus subgenomic mRNAs contain a leader se...   2001-12-17
# 1  CEACAM1 is a member of the carcinoembryonic an...   2002-05-01
# 2  Hepatitis C virus (HCV) is an important human ...   2001-07-16
# 3  The key enzyme in coronavirus polyprotein proc...   2002-07-01
# 4  Arteri-, corona-, toro- and roniviruses are ev...   2002-12-01
#
#                                              authors           journal  \
# 0  Pasternak, Alexander O.; van den Born, Erwin; ...  The EMBO Journal
# 1  Tan, Kemin; Zelus, Bruce D.; Meijers, Rob; Liu...  The EMBO Journal
# 2  Xu, Zhenming; Choi, Jinah; Yen, T.S.Benedict; ...            EMBO J
# 3  Anand, Kanchan; Palm, Gottfried J.; Mesters, J...  The EMBO Journal
# 4  van Vliet, A.L.W.; Smits, S.L.; Rottier, P.J.M...  The EMBO Journal
#
#   Microsoft Academic Paper ID WHO #Covidence  has_pdf_parse  \
# 0                         NaN            NaN           True
# 1                         NaN            NaN           True
# 2                         NaN            NaN           True
# 3                         NaN            NaN           True
# 4                         NaN            NaN           True
#
#    has_pmc_xml_parse  full_text_file  \
# 0               True  custom_license
# 1               True  custom_license
# 2               True  custom_license
# 3               True  custom_license
# 4               True  custom_license
#
#                                                  url
# 0  http://europepmc.org/articles/pmc125340?pdf=re...
# 1  http://europepmc.org/articles/pmc125375?pdf=re...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 3  http://europepmc.org/articles/pmc126080?pdf=re...
# 4  http://europepmc.org/articles/pmc136939?pdf=re...

# %%
# Inspect the shape of the metadata dataset:
meta_df.shape
# Out:
# (57366, 18)

# %% [markdown]
# #### 2. Extract data from json files that contain liturerature

# %%
# Grab all json files that contain all lituratures:
all_json = glob.glob(f'{root_path}/**/*.json', recursive=True)
len(all_json)
# Out:
# 68204

# %%
# Open 1 json file to see what the structure looks like:
with open(all_json[1]) as file:
    first_entry = json.load(file)
    print(json.dumps(first_entry, indent=4))
# Out:
# {
#     "paper_id": "PMC7109766",
#     "metadata": {
#         "title": "Reply to Tso et al",
#         "authors": [
#             {
#                 "first": "Xinchun",
#                 "middle": [],
#                 "last": "Chen",
#                 "suffix": "",
#                 "email": null,
#                 "affiliation": {}
#             },
#             {
#                 "first": "Boping",
#                 "middle": [],
#                 "last": "Zhou",
#                 "suffix": "",
#                 "email": null,
#                 "affiliation": {}
#             },
#             {
#                 "first": "Meizhong",
#                 "middle": [],
#                 "last": "Li",
#                 "suffix": "",
#                 "email": null,
#                 "affiliation": {}
#             },
#             {
#                 "first": "Xiaorong",
#                 "middle": [],
#                 "last": "Liang",
#                 "suffix": "",
#                 "email": null,
#                 "affiliation": {}
#             },
#             {
#                 "first": "Huosheng",
#                 "middle": [],
#                 "last": "Wang",
#                 "suffix": "",
#                 "email": null,
#                 "affiliation": {}
#             },
#             {
#                 "first": "Guilin",
#                 "middle": [],
#                 "last": "Yang",
#                 "suffix": "",
#                 "email": null,
#                 "affiliation": {}
#             },
#             {
#                 "first": "Wang",
#                 "middle": [],
#                 "last": "Hui",
#                 "suffix": "",
#                 "email": null,
#                 "affiliation": {}
#             },
#             {
#                 "first": "Xiaohua",
#                 "middle": [],
#                 "last": "Le",
#                 "suffix": "",
#                 "email": null,
#                 "affiliation": {}
#             }
#         ]
#     },
#     "body_text": [
#         {
#             "text": "\nTo the Editor\u2014We appreciate the letters from Tso et al. [1, 2] that expand on our study [3] of the serologic profile of severe acute respiratory syndrome (SARS). On the basis of the findings of our study, we are certain that IgG antibody persists for at least 60 days after the onset of symptoms. This is consistent with Tso et al.'s results, which, despite the different assays used, indicate that SARS-associated coronavirus (SARS CoV) immunoglobulin titers continue to increase from 15 days to 3 months after the onset of symptoms.",
#             "cite_spans": [
#                 {
#                     "start": 58,
#                     "end": 59,
#                     "mention": "1",
#                     "ref_id": "BIBREF0"
#                 },
#                 {
#                     "start": 61,
#                     "end": 62,
#                     "mention": "2",
#                     "ref_id": "BIBREF1"
#                 },
#                 {
#                     "start": 90,
#                     "end": 91,
#                     "mention": "3",
#                     "ref_id": "BIBREF2"
#                 }
#             ],
#             "section": "",
#             "ref_spans": []
#         },
#         {
#             "text": "Interestingly, the rate of seroconversion differs in the 2 studies, with an 83% rate of seroconversion reported in our study and a 100% rate of seroconversion reported in Tso et al.'s study [2]. This may have been a consequence of the different populations of patients and of the different assays used in the studies. Tso et al. selected 62 survivors from a group of 267 patients with SARS, among whom 78% had a 4-fold increase in SARS CoV immunoglobulin or a single titer of \u2a7e100 during their first 3 months of follow-up [2, 4]. This 78% rate of seroconversion in the 267 patients [4] was close to our observations of 75% on day 21 and 83% on day 60. According to several reports, the immunofluorescent assay used by Tso et al. is more sensitive than the ELISA used in our study [5\u20147]. Nevertheless, ELISA provides similar results and remains the most convenient and reliable test in both clinical practice and epidemiologic studies.",
#             "cite_spans": [
#                 {
#                     "start": 191,
#                     "end": 192,
#                     "mention": "2",
#                     "ref_id": "BIBREF1"
#                 },
#                 {
#                     "start": 523,
#                     "end": 524,
#                     "mention": "2",
#                     "ref_id": "BIBREF1"
#                 },
#                 {
#                     "start": 526,
#                     "end": 527,
#                     "mention": "4",
#                     "ref_id": "BIBREF3"
#                 },
#                 {
#                     "start": 781,
#                     "end": 784,
#                     "mention": "5\u20147",
#                     "ref_id": "BIBREF4"
#                 }
#             ],
#             "section": "",
#             "ref_spans": []
#         }
#     ],
#     "ref_entries": {},
#     "back_matter": [],
#     "bib_entries": {
#         "BIBREF0": {
#             "title": "Natural course of severe acute respiratory syndrome-associated coronavirus immunoglobulin after infection [letter]",
#             "authors": [
#                 {
#                     "first": "EYK",
#                     "middle": [],
#                     "last": "Tso",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "OTY",
#                     "middle": [],
#                     "last": "Tsang",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "B",
#                     "middle": [],
#                     "last": "Lam",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "TK",
#                     "middle": [],
#                     "last": "Ng",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "W",
#                     "middle": [],
#                     "last": "Lim",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "TST",
#                     "middle": [],
#                     "last": "Lai",
#                     "suffix": ""
#                 }
#             ],
#             "year": 2004,
#             "venue": "J Infect Dis",
#             "volume": "190",
#             "issn": "",
#             "pages": "1706-7.",
#             "other_ids": {
#                 "DOI": []
#             }
#         },
#         "BIBREF1": {
#             "title": "Persistence of physical symptoms in and abnormal laboratory findings for survivors of severe acute respiratory syndrome [letter]",
#             "authors": [
#                 {
#                     "first": "EYK",
#                     "middle": [],
#                     "last": "Tso",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "OTY",
#                     "middle": [],
#                     "last": "Tsang",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "KW",
#                     "middle": [],
#                     "last": "Choi",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "al",
#                     "middle": [],
#                     "last": "et",
#                     "suffix": ""
#                 }
#             ],
#             "year": 2004,
#             "venue": "Clin Infect Dis",
#             "volume": "38",
#             "issn": "",
#             "pages": null,
#             "other_ids": {
#                 "DOI": []
#             }
#         },
#         "BIBREF2": {
#             "title": "Serology of severe acute respiratory syndrome: implications for surveillance and outcome",
#             "authors": [
#                 {
#                     "first": "X",
#                     "middle": [],
#                     "last": "Chen",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "B",
#                     "middle": [],
#                     "last": "Zhou",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "M",
#                     "middle": [],
#                     "last": "Li",
#                     "suffix": ""
#                 }
#             ],
#             "year": 2004,
#             "venue": "J Infect Dis",
#             "volume": "189",
#             "issn": "",
#             "pages": "1158-63",
#             "other_ids": {
#                 "DOI": []
#             }
#         },
#         "BIBREF3": {
#             "title": "Outcomes and prognostic factors in 267 patients with severe acute respiratory syndrome in Hong Kong",
#             "authors": [
#                 {
#                     "first": "KW",
#                     "middle": [],
#                     "last": "Choi",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "TN",
#                     "middle": [],
#                     "last": "Chau",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "O",
#                     "middle": [],
#                     "last": "Tsang",
#                     "suffix": ""
#                 }
#             ],
#             "year": 2003,
#             "venue": "Ann Intern Med",
#             "volume": "139",
#             "issn": "",
#             "pages": "715-23",
#             "other_ids": {
#                 "DOI": []
#             }
#         },
#         "BIBREF4": {
#             "title": "Serologic and molecular biologic methods for SARS-associated coronavirus infection, Taiwan",
#             "authors": [
#                 {
#                     "first": "HS",
#                     "middle": [],
#                     "last": "Wu",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "SC",
#                     "middle": [],
#                     "last": "Chiu",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "TC",
#                     "middle": [],
#                     "last": "Tseng",
#                     "suffix": ""
#                 }
#             ],
#             "year": 2004,
#             "venue": "Emerg Infect Dis",
#             "volume": "10",
#             "issn": "",
#             "pages": "304-10",
#             "other_ids": {
#                 "DOI": []
#             }
#         },
#         "BIBREF5": {
#             "title": "Serum antibodies detection for serological diagnosis of severe acute respiratory syndrome [in Chinese]",
#             "authors": [],
#             "year": 2003,
#             "venue": "Zhonghua Jie He He Hu Xi Za Zhi",
#             "volume": "26",
#             "issn": "",
#             "pages": "339-42",
#             "other_ids": {
#                 "DOI": []
#             }
#         },
#         "BIBREF6": {
#             "title": "Immunofluorescence assay for serologic diagnosis of SARS",
#             "authors": [
#                 {
#                     "first": "PK",
#                     "middle": [],
#                     "last": "Chan",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "KC",
#                     "middle": [],
#                     "last": "Ng",
#                     "suffix": ""
#                 },
#                 {
#                     "first": "RC",
#                     "middle": [],
#                     "last": "Chan",
#                     "suffix": ""
#                 }
#             ],
#             "year": 2004,
#             "venue": "Emerg Infect Dis",
#             "volume": "10",
#             "issn": "",
#             "pages": "530-2",
#             "other_ids": {
#                 "DOI": []
#             }
#         }
#     }
# }

# %%
# Build helper function to read files:
class FileReader:
    def __init__(self, file_path):
        with open(file_path) as file:
            content = json.load(file)
            self.paper_id = content['paper_id'] #extract paper_id
            self.title = content['metadata']['title'] #extract paper title
            self.body_text = []
            # Body text
            for entry in content['body_text']:
                self.body_text.append(entry['text'])#extract body_text
            self.body_text = '\n'.join(self.body_text)
            # Extend Here
            #
            #
    def __repr__(self):
        return f'{self.paper_id}: {self.body_text[:300]}...'

# Use FileReader class to inspect the second row all_json, only showing the first 300 characters:
second_row = FileReader(all_json[1])
print(second_row)
# Out:
# PMC7109766:
# To the Editor—We appreciate the letters from Tso et al. [1, 2] that expand on our study [3] of the serologic profile of severe acute respiratory syndrome (SARS). On the basis of the findings of our study, we are certain that IgG antibody persists for at least 60 days after the onset of symptoms. Th...

# %%
# Load literatures into a dataframe:
dict_ = {'paper_id': [], 'title': [], 'body_text': []}
for idx, entry in enumerate(all_json):
    if idx % (len(all_json) // 10) == 0:
        print(f'Processing index: {idx} of {len(all_json)}')
    content = FileReader(entry)
    dict_['paper_id'].append(content.paper_id)
    dict_['title'].append(content.title)
    dict_['body_text'].append(content.body_text)
df_covid = pd.DataFrame(dict_, columns=['paper_id', 'title', 'body_text'])
# Out:
# Processing index: 0 of 68204
# Processing index: 6820 of 68204
# Processing index: 13640 of 68204
# Processing index: 20460 of 68204
# Processing index: 27280 of 68204
# Processing index: 34100 of 68204
# Processing index: 40920 of 68204
# Processing index: 47740 of 68204
# Processing index: 54560 of 68204
# Processing index: 61380 of 68204
# Processing index: 68200 of 68204

# %% [markdown]
# #### 3. Data cleaning and feature engineering

# %%
# Adding wordcount feature:
df_covid['body_word_count'] = df_covid['body_text'].apply(lambda x: len(x.strip().split()))
df_covid.head()
# Out:
#      paper_id                                              title  \
# 0  PMC2750777  The spike protein of SARS-CoV — a target for v...
# 1  PMC7109766                                 Reply to Tso et al
# 2  PMC7107989  Acute Respiratory Distress Syndrome and Pneumo...
# 3  PMC7121640  Autoimmune Processes in the Central Nervous Sy...
# 4  PMC7094896  Critics slam treatment for SARS as ineffective...
#
#                                            body_text  body_word_count
# 0                                                                   0
# 1  \nTo the Editor—We appreciate the letters from...              252
# 2  The sequence from bacterial pneumonia to ARDS ...             2630
# 3  The central nervous system (CNS) has been cons...             7123
# 4  Health authorities in Hong Kong are coming und...              452

# %%
df_covid.describe(include='all')
# Out:
#                                         paper_id  title body_text  \
# count                                      68204  68204     68204
# unique                                     68204  50029     65242
# top     5f7a653beae752fae3a898cbfce92cb2854a874a
# freq                                           1   4997      2373
# mean                                         NaN    NaN       NaN
# std                                          NaN    NaN       NaN
# min                                          NaN    NaN       NaN
# 25%                                          NaN    NaN       NaN
# 50%                                          NaN    NaN       NaN
# 75%                                          NaN    NaN       NaN
# max                                          NaN    NaN       NaN
#
#         body_word_count
# count      68204.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean        4346.978814
# std         8869.285139
# min            0.000000
# 25%         2066.000000
# 50%         3405.000000
# 75%         5148.000000
# max       748939.000000

# %% [markdown]
# Looking at the statistical description of the df_covid dataset, it looks like we have 65,242 unique body_text out of 68,204 entries, indicating that we have duplicate literatures. Let drop all duplicates to make sure that our dataset only contain unique documents.

# %%
# Drop duplicate research papers:
df_covid.drop_duplicates(['body_text'], inplace=True)

# %%
# Inspect the shape of the dataset after droping entries:
df_covid.shape
# Out:
# (65242, 4)

# %%
df_covid
# Out:
#                                        paper_id  \
# 0                                    PMC2750777
# 1                                    PMC7109766
# 2                                    PMC7107989
# 3                                    PMC7121640
# 4                                    PMC7094896
# ...                                         ...
# 68199  228650bc0429064d800d4b9c5fb0e00c2533a579
# 68200  2246e28681bde69c65dc9081df367bb661997f19
# 68201  577c6a13f9ef70e9756890fc66e98f537c01ac0a
# 68202  c5c2bc7a07670d6fb970d84a59aab3832752a3f1
# 68203  ba29366173f97f54a22e5c410b3d05e9a9649d28
#
#                                                    title  \
# 0      The spike protein of SARS-CoV — a target for v...
# 1                                     Reply to Tso et al
# 2      Acute Respiratory Distress Syndrome and Pneumo...
# 3      Autoimmune Processes in the Central Nervous Sy...
# 4      Critics slam treatment for SARS as ineffective...
# ...                                                  ...
# 68199  Lipidome profiles of postnatal day 2 vaginal s...
# 68200  Secondary Syphilis in Cali, Colombia: New Conc...
# 68201  Replication and shedding of MERS- CoV in Jamai...
# 68202  Role of the ERK1/2 Signaling Pathway in the Re...
# 68203  Foodborne Transmission of Deformed Wing Virus ...
#
#                                                body_text  body_word_count
# 0                                                                       0
# 1      \nTo the Editor—We appreciate the letters from...              252
# 2      The sequence from bacterial pneumonia to ARDS ...             2630
# 3      The central nervous system (CNS) has been cons...             7123
# 4      Health authorities in Hong Kong are coming und...              452
# ...                                                  ...              ...
# 68199  Early nutritional environment affects long ter...             4139
# 68200  Syphilis is a sexually transmitted disease (ST...             5621
# 68201  Scientific RepoRts | 6:21878 | DOI: 10 .1038/s...             2832
# 68202  Arenaviruses are enveloped RNA viruses contain...             4805
# 68203  Emerging infectious diseases (EIDs) can cause ...             3236
#
# [65242 rows x 4 columns]

# %%
# Merge meta_df with df_covid:
covid19 = pd.merge(meta_df, df_covid, how='inner', on='title')

# %%
# Only use features that are useful to our analysis:
covid19 = covid19[['sha', 'pmcid', 'paper_id', 'source_x', 'title', 'license', 'abstract', 
                   'publish_time', 'journal', 'body_text', 'body_word_count', 'url']]

# %%
# Print out the first 10 rows of the new covid19 dataset:
covid19.head(10)
# Out:
#                                         sha      pmcid  \
# 0  b2897e1277f56641193a6db73825f707eed3e4c9  PMC125340
# 1  e3d0d482ebd9a8ba81c254cc433f314142e72174  PMC125375
# 2  cf584e00f637cbd8f1bb35f3f09f5ed07b71aeb0  PMC126080
# 3  dde02f11923815e6a16a31dd6298c46b109c5dfa  PMC136939
# 4  dde02f11923815e6a16a31dd6298c46b109c5dfa  PMC136939
# 5  1e1286db212100993d03cc22374b624f7caee956  PMC140314
# 6  8ae137c8da1607b3a8e4c946c07ca8bda67f88ac  PMC156578
# 7  8ae137c8da1607b3a8e4c946c07ca8bda67f88ac  PMC156578
# 8  23bc55d6f63fab18b02004483888db2b6a0bfa48  PMC169038
# 9                                       NaN  PMC193621
#
#                                    paper_id source_x  \
# 0                                 PMC125340      PMC
# 1                                 PMC125375      PMC
# 2                                 PMC126080      PMC
# 3                                 PMC136939      PMC
# 4  dde02f11923815e6a16a31dd6298c46b109c5dfa      PMC
# 5                                 PMC140314      PMC
# 6                                 PMC156578      PMC
# 7  8ae137c8da1607b3a8e4c946c07ca8bda67f88ac      PMC
# 8                                 PMC169038      PMC
# 9                                 PMC193621      PMC
#
#                                                title license  \
# 0  Sequence requirements for RNA strand transfer ...     unk
# 1  Crystal structure of murine sCEACAM1a[1,4]: a ...     unk
# 2  Structure of coronavirus main proteinase revea...     unk
# 3  Discontinuous and non-discontinuous subgenomic...     unk
# 4  Discontinuous and non-discontinuous subgenomic...     unk
# 5  Airborne rhinovirus detection and effect of ul...   no-cc
# 6    Discovering human history from stomach bacteria   no-cc
# 7    Discovering human history from stomach bacteria   no-cc
# 8  Prokaryotic-style frameshifting in a plant tra...     unk
# 9     A new recruit for the army of the men of death   no-cc
#
#                                             abstract publish_time  \
# 0  Nidovirus subgenomic mRNAs contain a leader se...   2001-12-17
# 1  CEACAM1 is a member of the carcinoembryonic an...   2002-05-01
# 2  The key enzyme in coronavirus polyprotein proc...   2002-07-01
# 3  Arteri-, corona-, toro- and roniviruses are ev...   2002-12-01
# 4  Arteri-, corona-, toro- and roniviruses are ev...   2002-12-01
# 5  BACKGROUND: Rhinovirus, the most common cause ...   2003-01-13
# 6  Recent analyses of human pathogens have reveal...   2003-04-28
# 7  Recent analyses of human pathogens have reveal...   2003-04-28
# 8  Ribosomal frameshifting signals are found in m...   2003-08-01
# 9  The army of the men of death, in John Bunyan's...   2003-06-27
#
#              journal                                          body_text  \
# 0   The EMBO Journal  The genetic information of RNA viruses is orga...
# 1   The EMBO Journal  Carcinoembryonic antigen (CEA; CD66e) was init...
# 2   The EMBO Journal  Transmissible gastroenteritis virus (TGEV) bel...
# 3   The EMBO Journal  Positive (+)-strand RNA viruses have developed...
# 4   The EMBO Journal  Positive (+)-strand RNA viruses have developed...
# 5  BMC Public Health  Rhinoviruses have been associated with 40% to ...
# 6        Genome Biol  Charles Darwin recognized that the distributio...
# 7        Genome Biol  Charles Darwin recognized that the distributio...
# 8   The EMBO Journal  The elongation phase of protein synthesis is a...
# 9        Genome Biol  The message was dated Tuesday, 2 June 2003. "F...
#
#    body_word_count                                                url
# 0             5942  http://europepmc.org/articles/pmc125340?pdf=re...
# 1             5673  http://europepmc.org/articles/pmc125375?pdf=re...
# 2             5667  http://europepmc.org/articles/pmc126080?pdf=re...
# 3             5075  http://europepmc.org/articles/pmc136939?pdf=re...
# 4             6061  http://europepmc.org/articles/pmc136939?pdf=re...
# 5             3366  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 6             1474  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 7             1781  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 8             5774  http://europepmc.org/articles/pmc169038?pdf=re...
# 9             1572  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...

# %%
# Print out the shape of the covid19 dataset:
covid19.shape
# Out:
# (42690, 12)

# %%
# Remove any liturature duplicates & split publish_time column to year and month:
covid19 = covid19.drop_duplicates(subset=['body_text', 'abstract'])
covid19 = covid19.drop(index=1276).reset_index() # this row contains nan value for abstract

# Split publish_time to extract month and year data:
covid19['publish_year'] = pd.to_datetime(covid19['publish_time'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
covid19['publish_month'] = pd.to_datetime(covid19['publish_time'], errors='coerce').apply(lambda x: str(x).split('-')[1] if x != np.nan else np.nan)

# Change datatypes of month and year features:
covid19['publish_year'] = covid19['publish_year'].astype('int64')
covid19['publish_month'] = covid19['publish_month'].astype('int64')

# Drop publish_time column now that we don't need it anymore:
covid19.drop('publish_time', axis=1, inplace=True)

# %%
# Inspect the shape of the dataset:
print('The shape of the dataset is: {}'.format(covid19.shape))
print('')

# Inspect any missing values in percentage:
missing_values = covid19.isnull().sum()/len(covid19)*100
print('The features with missing values are:\n{}'.format(missing_values[missing_values>0]))
# Out:
# The shape of the dataset is: (41949, 14)
#
# The features with missing values are:
# sha         2.524494
# pmcid       6.631862
# abstract    6.548428
# journal     4.212258
# url         0.009535
# dtype: float64

# %%
# Data imputation:
covid19['abstract'] = covid19['abstract'].fillna('unknown', axis=0)
covid19['journal'] = covid19['journal'].fillna(covid19['journal'].mode()[0], axis=0)

# %%
covid19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41949 entries, 0 to 41948
# Data columns (total 14 columns):
# index              41949 non-null int64
# sha                40890 non-null object
# pmcid              39167 non-null object
# paper_id           41949 non-null object
# source_x           41949 non-null object
# title              41949 non-null object
# license            41949 non-null object
# abstract           41949 non-null object
# journal            41949 non-null object
# body_text          41949 non-null object
# body_word_count    41949 non-null int64
# url                41945 non-null object
# publish_year       41949 non-null int64
# publish_month      41949 non-null int64
# dtypes: int64(4), object(10)
# memory usage: 4.5+ MB

# %%
# Drop unused columns:
covid19 = covid19.drop(['index', 'sha', 'pmcid'], axis=1)

# %%
covid19
# Out:
#                                        paper_id  source_x  \
# 0                                     PMC125340       PMC
# 1                                     PMC125375       PMC
# 2                                     PMC126080       PMC
# 3                                     PMC136939       PMC
# 4      dde02f11923815e6a16a31dd6298c46b109c5dfa       PMC
# ...                                         ...       ...
# 41944  2d502e7bb600b3f1b16fa83995717993cbe316e7       PMC
# 41945  2e237dc7ffdacf42c76c0671bea72fae2a3ec9e1       PMC
# 41946  29e61d2288dcd264a7bbca9fdd23f6ed4f09cbc1  Elsevier
# 41947  2c01b65a4468d43dad054457c80d05d5a2715ac6  Elsevier
# 41948  f7b5270bed0faacf023c05cb6ff681f31bf5c2c4  Elsevier
#
#                                                    title    license  \
# 0      Sequence requirements for RNA strand transfer ...        unk
# 1      Crystal structure of murine sCEACAM1a[1,4]: a ...        unk
# 2      Structure of coronavirus main proteinase revea...        unk
# 3      Discontinuous and non-discontinuous subgenomic...        unk
# 4      Discontinuous and non-discontinuous subgenomic...        unk
# ...                                                  ...        ...
# 41944  Short-Sighted Virus Evolution and a Germline H...      cc-by
# 41945  Short-Sighted Virus Evolution and a Germline H...      cc-by
# 41946  An immunosuppressed Syrian golden hamster mode...  els-covid
# 41947  Structural model of the SARS coronavirus E cha...  els-covid
# 41948          Immunomodulators as an antimicrobial tool  els-covid
#
#                                                 abstract  \
# 0      Nidovirus subgenomic mRNAs contain a leader se...
# 1      CEACAM1 is a member of the carcinoembryonic an...
# 2      The key enzyme in coronavirus polyprotein proc...
# 3      Arteri-, corona-, toro- and roniviruses are ev...
# 4      Arteri-, corona-, toro- and roniviruses are ev...
# ...                                                  ...
# 41944  With extremely short generation times and high...
# 41945  With extremely short generation times and high...
# 41946  Abstract Several small animal models have been...
# 41947  Abstract Coronaviruses (CoV) cause common cold...
# 41948  The spectrum of infectious diseases has shifte...
#
#                                                  journal  \
# 0                                       The EMBO Journal
# 1                                       The EMBO Journal
# 2                                       The EMBO Journal
# 3                                       The EMBO Journal
# 4                                       The EMBO Journal
# ...                                                  ...
# 41944                                   Trends Microbiol
# 41945                                   Trends Microbiol
# 41946                                           Virology
# 41947  Biochimica et Biophysica Acta (BBA) - Biomembr...
# 41948                    Current Opinion in Microbiology
#
#                                                body_text  body_word_count  \
# 0      The genetic information of RNA viruses is orga...             5942
# 1      Carcinoembryonic antigen (CEA; CD66e) was init...             5673
# 2      Transmissible gastroenteritis virus (TGEV) bel...             5667
# 3      Positive (+)-strand RNA viruses have developed...             5075
# 4      Positive (+)-strand RNA viruses have developed...             6061
# ...                                                  ...              ...
# 41944  With extremely short generation times and high...             6119
# 41945  Susceptibility to short-sighted evolution will...             5270
# 41946  The severe acute respiratory syndrome coronavi...             4918
# 41947  Coronaviruses (CoV) typically affect the respi...             3296
# 41948  Liise-anne Pirofski 1,2 and Arturo Casadevall ...             3362
#
#                                                      url  publish_year  \
# 0      http://europepmc.org/articles/pmc125340?pdf=re...          2001
# 1      http://europepmc.org/articles/pmc125375?pdf=re...          2002
# 2      http://europepmc.org/articles/pmc126080?pdf=re...          2002
# 3      http://europepmc.org/articles/pmc136939?pdf=re...          2002
# 4      http://europepmc.org/articles/pmc136939?pdf=re...          2002
# ...                                                  ...           ...
# 41944  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          2017
# 41945  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          2017
# 41946        https://doi.org/10.1016/j.virol.2008.07.026          2008
# 41947       https://doi.org/10.1016/j.bbamem.2018.02.017          2018
# 41948          https://doi.org/10.1016/j.mib.2006.08.004          2006
#
#        publish_month
# 0                 12
# 1                  5
# 2                  7
# 3                 12
# 4                 12
# ...              ...
# 41944              4
# 41945              4
# 41946             10
# 41947              6
# 41948             10
#
# [41949 rows x 11 columns]

# %%
# Exclude any rows with body_text <20 words:
covid19 = covid19[covid19['body_word_count'] > 20]

# %%
covid19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41843 entries, 0 to 41948
# Data columns (total 11 columns):
# paper_id           41843 non-null object
# source_x           41843 non-null object
# title              41843 non-null object
# license            41843 non-null object
# abstract           41843 non-null object
# journal            41843 non-null object
# body_text          41843 non-null object
# body_word_count    41843 non-null int64
# url                41839 non-null object
# publish_year       41843 non-null int64
# publish_month      41843 non-null int64
# dtypes: int64(3), object(8)
# memory usage: 3.8+ MB

# %% [markdown]
# #### 4. Write the result into a new .csv file to use later

# %%
# Write the result into a new .csv file in the directory:
corona_out = covid19.to_csv('kaggle_covid-19_clean_format.csv')
